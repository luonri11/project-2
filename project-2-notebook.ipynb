# %%
import pandas as pd
from sqlalchemy import create_engine
from config import pg_pass
from config import pg_user
import psycopg2

# %%
house_csv = "resources/melb_data.csv"
house_df = pd.read_csv(house_csv)
house_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
venus_csv = "resources/Melbourne_venues.csv"
venus_df = pd.read_csv(venus_csv)
venus_df.head()
# Out:
#    Unnamed: 0       Street  Suburb  Latitude  Longitude  \
# 0           0  Anderson Rd  Albion  -37.7852   144.8272
# 1           1  Anderson Rd  Albion  -37.7852   144.8272
# 2           2  Anderson Rd  Albion  -37.7852   144.8272
# 3           3  Anderson Rd  Albion  -37.7852   144.8272
# 4           4  Anderson Rd  Albion  -37.7852   144.8272
#
#                          Venue  Venue Latitude  Venue Longitude  \
# 0  Cố Đô Vietnamese Restaurant      -37.785639       144.831891
# 1               Diamond Palace      -37.785903       144.831890
# 2              Pho Hien Saigon      -37.784650       144.832178
# 3            Fresh Chilli Deli      -37.783545       144.832313
# 4          Afghan Master Kebab      -37.784865       144.832678
#
#           Venue Category
# 0  Vietnamese Restaurant
# 1     Chinese Restaurant
# 2  Vietnamese Restaurant
# 3                 Bakery
# 4      Afghan Restaurant

# %%
house_cols = ["Suburb", "Address", "Price", "CouncilArea"]
house_transformed = house_df[house_cols].copy()

house_transformed.head()
# Out:
#        Suburb           Address      Price CouncilArea
# 0  Abbotsford      85 Turner St  1480000.0       Yarra
# 1  Abbotsford   25 Bloomburg St  1035000.0       Yarra
# 2  Abbotsford      5 Charles St  1465000.0       Yarra
# 3  Abbotsford  40 Federation La   850000.0       Yarra
# 4  Abbotsford       55a Park St  1600000.0       Yarra

# %%
venue_cols = ["Suburb", "Venue Category", "Venue"]
venue_transformed = venus_df[venue_cols].copy()


venue_transformed.head()
# Out:
#    Suburb         Venue Category                        Venue
# 0  Albion  Vietnamese Restaurant  Cố Đô Vietnamese Restaurant
# 1  Albion     Chinese Restaurant               Diamond Palace
# 2  Albion  Vietnamese Restaurant              Pho Hien Saigon
# 3  Albion                 Bakery            Fresh Chilli Deli
# 4  Albion      Afghan Restaurant          Afghan Master Kebab

# %%
connection_string = (f'{pg_user}:{pg_pass}@localhost:5432/melbourne_data_db')
engine = create_engine(f'postgresql://{connection_string}')

engine.table_names()
# Out:
# c:\Users\Kevin\anaconda3\envs\bootcamp\lib\site-packages\ipykernel_launcher.py:4: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\Kevin\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3255         try:
# -> 3256             return fn()
#    3257         except dialect.dbapi.Error as e:
#
# c:\Users\Kevin\anaconda3\envs\bootcamp\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ...
