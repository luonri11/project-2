# %%
# Import Dependencies
import pandas as pd
from sqlalchemy import create_engine
#from config import pg_pass
#from config import pg_user
import psycopg2

# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot')

# %%
# create house df from csv
house_csv = "resources/melb_data.csv"
house_df = pd.read_csv(house_csv)
house_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
# create venues df from csv
venue_csv = "resources/Melbourne_venues.csv"
venue_df = pd.read_csv(venue_csv)
venue_df.head()
# Out:
#    Unnamed: 0       Street  Suburb  Latitude  Longitude  \
# 0           0  Anderson Rd  Albion  -37.7852   144.8272
# 1           1  Anderson Rd  Albion  -37.7852   144.8272
# 2           2  Anderson Rd  Albion  -37.7852   144.8272
# 3           3  Anderson Rd  Albion  -37.7852   144.8272
# 4           4  Anderson Rd  Albion  -37.7852   144.8272
#
#                          Venue  Venue Latitude  Venue Longitude  \
# 0  Cố Đô Vietnamese Restaurant      -37.785639       144.831891
# 1               Diamond Palace      -37.785903       144.831890
# 2              Pho Hien Saigon      -37.784650       144.832178
# 3            Fresh Chilli Deli      -37.783545       144.832313
# 4          Afghan Master Kebab      -37.784865       144.832678
#
#           Venue Category
# 0  Vietnamese Restaurant
# 1     Chinese Restaurant
# 2  Vietnamese Restaurant
# 3                 Bakery
# 4      Afghan Restaurant

# %%
# transform house table
house_mel = ["Suburb", "Address", "Price", "CouncilArea","Lattitude","Longtitude"]
melbourne_housing = house_df[house_mel].copy()

# check new list
melbourne_housing.head()
# Out:
#        Suburb           Address      Price CouncilArea  Lattitude  Longtitude
# 0  Abbotsford      85 Turner St  1480000.0       Yarra   -37.7996    144.9984
# 1  Abbotsford   25 Bloomburg St  1035000.0       Yarra   -37.8079    144.9934
# 2  Abbotsford      5 Charles St  1465000.0       Yarra   -37.8093    144.9944
# 3  Abbotsford  40 Federation La   850000.0       Yarra   -37.7969    144.9969
# 4  Abbotsford       55a Park St  1600000.0       Yarra   -37.8072    144.9941

# %%
# Correct spelling mistakes
melbourne_housing= melbourne_housing.rename(columns={"Lattitude":"Latitude","Longtitude":"Longitude"} )
melbourne_housing.head()
# Out:
#        Suburb           Address      Price CouncilArea  Latitude  Longitude
# 0  Abbotsford      85 Turner St  1480000.0       Yarra  -37.7996   144.9984
# 1  Abbotsford   25 Bloomburg St  1035000.0       Yarra  -37.8079   144.9934
# 2  Abbotsford      5 Charles St  1465000.0       Yarra  -37.8093   144.9944
# 3  Abbotsford  40 Federation La   850000.0       Yarra  -37.7969   144.9969
# 4  Abbotsford       55a Park St  1600000.0       Yarra  -37.8072   144.9941

# %%
# Mean data by suburb
house_by_suburb_df = melbourne_housing.groupby('Suburb').mean()
house_by_suburb_df.head()
# Out:
#                      Price   Latitude   Longitude
# Suburb
# Abbotsford    1.060366e+06 -37.804339  144.997176
# Aberfeldie    1.277455e+06 -37.759280  144.897587
# Airport West  7.566567e+05 -37.723399  144.879635
# Albanvale     5.370833e+05 -37.745640  144.770878
# Albert Park   1.941355e+06 -37.844127  144.953107

# %%
# Mean data by council area
house_by_suburb_df = melbourne_housing.groupby('CouncilArea').mean()
house_by_suburb_df.head()
# Out:
#                     Price   Latitude   Longitude
# CouncilArea
# Banyule      9.444280e+05 -37.740957  145.065046
# Bayside      1.652168e+06 -37.926146  145.010322
# Boroondara   1.647217e+06 -37.822077  145.062958
# Brimbank     6.472007e+05 -37.767510  144.819741
# Cardinia     5.731250e+05 -38.042975  145.426144

# %%
x = np.array(melbourne_housing["Suburb"])
y = np.array(melbourne_housing["Price"])


fig = plt.figure(figsize=(10, 50))
  
plt.barh(x, y, color='blue')
  
plt.xlabel("Suburb")
plt.ylabel("Price")
plt.title("Average price by suburb")

plt.show()

# %%
# transform venue table
venue_melb= ["Suburb", "Venue Category", "Venue","Latitude","Longitude"]
melbourne_venue = venue_df[venue_melb].copy()

melbourne_venue
# Out:
#      Suburb         Venue Category                        Venue  Latitude  \
# 0    Albion  Vietnamese Restaurant  Cố Đô Vietnamese Restaurant  -37.7852
# 1    Albion     Chinese Restaurant               Diamond Palace  -37.7852
# 2    Albion  Vietnamese Restaurant              Pho Hien Saigon  -37.7852
# 3    Albion                 Bakery            Fresh Chilli Deli  -37.7852
# 4    Albion      Afghan Restaurant          Afghan Master Kebab  -37.7852
# ..      ...                    ...                          ...       ...
# 459  Toorak    Japanese Restaurant               Orita Japanese  -37.8421
# 460  Toorak  Australian Restaurant                        Quaff  -37.8421
# 461  Toorak             Smoke Shop   Alexanders Cigar Merchants  -37.8421
# 462  Toorak          Shopping Mall                  Trak Centre  -37.8421
# 463  Toorak          Grocery Store                      Safeway  -37.8421
#
#      Longitude
# 0     144.8272
# 1     144.8272
# 2     144.8272
# 3     144.8272
# 4     144.8272
# ..         ...
# 459   145.0104
# 460   145.0104
# 461   145.0104
# 462   145.0104
# 463   145.0104
#
# [464 rows x 5 columns]

# %%
melbourne_venue= melbourne_venue.rename(columns={"Venue Category":"Venuecategory"})
# melbourne_venue

# %%
# create engine for postgresql
#rds_connection_string = "postgres:Pwd46999@localhost:5432/Melb_data_db"

rds_connection_string = "postgres:postgres@localhost:5432/Melb_data_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# check table names
engine.table_names()
# Out:
# c:\Users\User\anaconda3\envs\bootcamp\lib\site-packages\ipykernel_launcher.py:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
# ['melbor_housing', 'melbor_venue', 'melbor_house']

# %%
# Write records stored in a DataFrame to a SQL database
house_df.to_sql(name='melbor_housing', con=engine, if_exists='append', index=False)
melbourne_venue.to_sql(name='melbor_venue', con=engine, if_exists='append', index=False)
melbourne_housing.to_sql(name='melbor_house', con=engine, if_exists='append', index=False)

# %%
# Run query for venues
pd.read_sql_query('select * from melbor_venue', con=engine).head()
# Out:
#    Suburb          Venuecategory                        Venue  Latitude  \
# 0  Albion  Vietnamese Restaurant  Cố Đô Vietnamese Restaurant  -37.7852
# 1  Albion     Chinese Restaurant               Diamond Palace  -37.7852
# 2  Albion  Vietnamese Restaurant              Pho Hien Saigon  -37.7852
# 3  Albion                 Bakery            Fresh Chilli Deli  -37.7852
# 4  Albion      Afghan Restaurant          Afghan Master Kebab  -37.7852
#
#    Longitude
# 0   144.8272
# 1   144.8272
# 2   144.8272
# 3   144.8272
# 4   144.8272

# %%
# run query for housing
pd.read_sql_query('select * from melbor_house', con=engine).head()
# Out:
#        Suburb           Address      Price CouncilArea  Latitude  Longitude
# 0  Abbotsford      85 Turner St  1480000.0       Yarra  -37.7996   144.9984
# 1  Abbotsford   25 Bloomburg St  1035000.0       Yarra  -37.8079   144.9934
# 2  Abbotsford      5 Charles St  1465000.0       Yarra  -37.8093   144.9944
# 3  Abbotsford  40 Federation La   850000.0       Yarra  -37.7969   144.9969
# 4  Abbotsford       55a Park St  1600000.0       Yarra  -37.8072   144.9941

# %%
# check number of times each suburb appears in the table for venues
melbourne_venue["Suburb"].value_counts()
# Out:
# Melbourne          200
# Hawthorn            70
# Carnegie            35
# Footscray           27
# Melton              27
# Toorak              19
# Albion              15
# Glen Huntly          9
# Murrumbeena          9
# Caulfield            7
# Kingsville           6
# Ormond               6
# Reservoir            6
# Epping               5
# Bacchus Marsh        5
# Glen Iris            4
# Caulfield East       4
# Pascoe Vale          4
# Caulfield South      3
# Melton South         2
# Glenroy              1
# Name: Suburb, dtype: int64

# %%
# check number of times each suburb appears in the table for housing
melbourne_housing["Suburb"].value_counts()
# Out:
# Reservoir         359
# Richmond          260
# Bentleigh East    249
# Preston           239
# Brunswick         222
#                  ...
# Sandhurst           1
# Bullengarook        1
# Croydon South       1
# Montrose            1
# Monbulk             1
# Name: Suburb, Length: 314, dtype: int64

# %%
# Join the venue and housing tables
inner_join_df=pd.merge(melbourne_housing,melbourne_venue, on='Suburb', how='inner')
inner_join_df
# Out:
#               Suburb         Address     Price CouncilArea  Latitude_x  \
# 0           Carnegie  1/60 Moonya Rd  820000.0   Glen Eira   -37.89700
# 1           Carnegie  1/60 Moonya Rd  820000.0   Glen Eira   -37.89700
# 2           Carnegie  1/60 Moonya Rd  820000.0   Glen Eira   -37.89700
# 3           Carnegie  1/60 Moonya Rd  820000.0   Glen Eira   -37.89700
# 4           Carnegie  1/60 Moonya Rd  820000.0   Glen Eira   -37.89700
# ...              ...             ...       ...         ...         ...
# 40010  Bacchus Marsh    4 Lidgett St  285000.0   Moorabool   -37.67344
# 40011  Bacchus Marsh    4 Lidgett St  285000.0   Moorabool   -37.67344
# 40012  Bacchus Marsh    4 Lidgett St  285000.0   Moorabool   -37.67344
# 40013  Bacchus Marsh    4 Lidgett St  285000.0   Moorabool   -37.67344
# 40014  Bacchus Marsh    4 Lidgett St  285000.0   Moorabool   -37.67344
#
#        Longitude_x         Venuecategory                      Venue  \
# 0        145.06230   Japanese Restaurant  Shyun Japanese Restaurant
# 1        145.06230          Burger Joint                    Grill'd
# 2        145.06230            Bagel Shop               Huff Bagelry
# 3        145.06230     Korean Restaurant            Mrs Kim's Grill
# 4        145.06230                Bakery         Koornang Hot Bread
# ...            ...                   ...                        ...
# 40010    144.43181                  Café    Baby Black Espresso Bar
# 40011    144.43181           Supermarket                  Foodworks
# 40012    144.43181  Fast Food Restaurant          Kfc Bacchus Marsh
# 40013    144.43181  Fast Food Restaurant                 McDonald's
# 40014    144.43181                  Café          Loot Bar And Cafe
#
#        Latitude_y  Longitude_y
# 0       -37.88750    145.05990
# 1       -37.88750    145.05990
# 2       -37.88750    145.05990
# 3       -37.88750    145.05990
# 4       -37.88750    145.05990
# ...           ...          ...
# 40010   -37.67344    144.43181
# 40011   -37.67344    144.43181
# 40012   -37.67344    144.43181
# 40013   -37.67344    144.43181
# 40014   -37.67344    144.43181
#
# [40015 rows x 10 columns]

# %%
# check value_counts for suburbs 
inner_join_df["Suburb"].value_counts()
# Out:
# Hawthorn           13370
# Melbourne           9200
# Carnegie            5110
# Footscray           3564
# Reservoir           2154
# Toorak              1900
# Glen Iris            780
# Murrumbeena          738
# Pascoe Vale          684
# Albion               615
# Ormond               498
# Melton               324
# Epping               260
# Kingsville           204
# Glenroy              159
# Glen Huntly          153
# Caulfield South      141
# Caulfield             84
# Caulfield East        36
# Melton South          36
# Bacchus Marsh          5
# Name: Suburb, dtype: int64

# %%
# check value_counts for venue categories
inner_join_df["Venuecategory"].value_counts()
# Out:
# Café                   4938
# Japanese Restaurant    1829
# Coffee Shop            1456
# Korean Restaurant      1311
# Pizza Place            1140
#                        ...
# Electronics Store        12
# Pharmacy                 12
# Bus Station              12
# Train                     9
# Rental Car Location       9
# Name: Venuecategory, Length: 127, dtype: int64

# %%
# Venues type and avverage price of housing table
Summary_stat_df= inner_join_df.groupby(["Suburb","Venuecategory"])

Summary_stat_df.head()
# Out:
#               Suburb         Address     Price CouncilArea  Latitude_x  \
# 0           Carnegie  1/60 Moonya Rd  820000.0   Glen Eira   -37.89700
# 1           Carnegie  1/60 Moonya Rd  820000.0   Glen Eira   -37.89700
# 2           Carnegie  1/60 Moonya Rd  820000.0   Glen Eira   -37.89700
# 3           Carnegie  1/60 Moonya Rd  820000.0   Glen Eira   -37.89700
# 4           Carnegie  1/60 Moonya Rd  820000.0   Glen Eira   -37.89700
# ...              ...             ...       ...         ...         ...
# 40010  Bacchus Marsh    4 Lidgett St  285000.0   Moorabool   -37.67344
# 40011  Bacchus Marsh    4 Lidgett St  285000.0   Moorabool   -37.67344
# 40012  Bacchus Marsh    4 Lidgett St  285000.0   Moorabool   -37.67344
# 40013  Bacchus Marsh    4 Lidgett St  285000.0   Moorabool   -37.67344
# 40014  Bacchus Marsh    4 Lidgett St  285000.0   Moorabool   -37.67344
#
#        Longitude_x         Venuecategory                      Venue  \
# 0        145.06230   Japanese Restaurant  Shyun Japanese Restaurant
# 1        145.06230          Burger Joint                    Grill'd
# 2        145.06230            Bagel Shop               Huff Bagelry
# 3        145.06230     Korean Restaurant            Mrs Kim's Grill
# 4        145.06230                Bakery         Koornang Hot Bread
# ...            ...                   ...                        ...
# 40010    144.43181                  Café    Baby Black Espresso Bar
# 40011    144.43181           Supermarket                  Foodworks
# 40012    144.43181  Fast Food Restaurant          Kfc Bacchus Marsh
# 40013    144.43181  Fast Food Restaurant                 McDonald's
# 40014    144.43181                  Café          Loot Bar And Cafe
#
#        Latitude_y  Longitude_y
# 0       -37.88750    145.05990
# 1       -37.88750    145.05990
# 2       -37.88750    145.05990
# 3       -37.88750    145.05990
# 4       -37.88750    145.05990
# ...           ...          ...
# 40010   -37.67344    144.43181
# 40011   -37.67344    144.43181
# 40012   -37.67344    144.43181
# 40013   -37.67344    144.43181
# 40014   -37.67344    144.43181
#
# [1345 rows x 10 columns]

# %%
# Number of venues by catergory per suburb
Summary_stat_df["Suburb"].value_counts()
# Out:
# Suburb  Venuecategory        Suburb
# Albion  Afghan Restaurant    Albion     41
#         Asian Restaurant     Albion     41
#         Bakery               Albion     41
#         Café                 Albion     41
#         Chinese Restaurant   Albion     82
#                                       ...
# Toorak  Italian Restaurant   Toorak    100
#         Japanese Restaurant  Toorak    100
#         Rock Club            Toorak    100
#         Shopping Mall        Toorak    200
#         Smoke Shop           Toorak    100
# Name: Suburb, Length: 271, dtype: int64

# %%
suburb_list=['Hawthorn','Melbourne','Carnegie','Footscray',
            'Reservoir','Toorak','Glen Iris','Murrumbeena',
            'Pascoe Vale','Albion','Ormond','Melton','Epping',
            'Kingsville' ,'Glenroy','Glen Huntly','Caulfield South',
            'Caulfield','Caulfield East','Bacchus Marsh']

suburb_df=inner_join_df[inner_join_df["Suburb"].isin(suburb_list)]
suburb_df
# Out:
#               Suburb         Address     Price CouncilArea  Latitude_x  \
# 0           Carnegie  1/60 Moonya Rd  820000.0   Glen Eira   -37.89700
# 1           Carnegie  1/60 Moonya Rd  820000.0   Glen Eira   -37.89700
# 2           Carnegie  1/60 Moonya Rd  820000.0   Glen Eira   -37.89700
# 3           Carnegie  1/60 Moonya Rd  820000.0   Glen Eira   -37.89700
# 4           Carnegie  1/60 Moonya Rd  820000.0   Glen Eira   -37.89700
# ...              ...             ...       ...         ...         ...
# 40010  Bacchus Marsh    4 Lidgett St  285000.0   Moorabool   -37.67344
# 40011  Bacchus Marsh    4 Lidgett St  285000.0   Moorabool   -37.67344
# 40012  Bacchus Marsh    4 Lidgett St  285000.0   Moorabool   -37.67344
# 40013  Bacchus Marsh    4 Lidgett St  285000.0   Moorabool   -37.67344
# 40014  Bacchus Marsh    4 Lidgett St  285000.0   Moorabool   -37.67344
#
#        Longitude_x         Venuecategory                      Venue  \
# 0        145.06230   Japanese Restaurant  Shyun Japanese Restaurant
# 1        145.06230          Burger Joint                    Grill'd
# 2        145.06230            Bagel Shop               Huff Bagelry
# 3        145.06230     Korean Restaurant            Mrs Kim's Grill
# 4        145.06230                Bakery         Koornang Hot Bread
# ...            ...                   ...                        ...
# 40010    144.43181                  Café    Baby Black Espresso Bar
# 40011    144.43181           Supermarket                  Foodworks
# 40012    144.43181  Fast Food Restaurant          Kfc Bacchus Marsh
# 40013    144.43181  Fast Food Restaurant                 McDonald's
# 40014    144.43181                  Café          Loot Bar And Cafe
#
#        Latitude_y  Longitude_y
# 0       -37.88750    145.05990
# 1       -37.88750    145.05990
# 2       -37.88750    145.05990
# 3       -37.88750    145.05990
# 4       -37.88750    145.05990
# ...           ...          ...
# 40010   -37.67344    144.43181
# 40011   -37.67344    144.43181
# 40012   -37.67344    144.43181
# 40013   -37.67344    144.43181
# 40014   -37.67344    144.43181
#
# [39979 rows x 10 columns]

# %%
inner_join_df.to_sql(name='melbor_venhouse', con=engine, if_exists='append', index=False)
